# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (8,5)
sns.set_style("whitegrid")

# %%
df=pd.read_csv("C:/Users/Siddhi/Downloads/archive/sales.csv.csv")

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.fillna(2)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df = df.dropna(subset=['Order Date'])

# %%
df['Order Date']
# Out:
# 0       08/11/2017
# 1       08/11/2017
# 2       12/06/2017
# 3       11/10/2016
# 4       11/10/2016
#            ...
# 9795    21/05/2017
# 9796    12/01/2016
# 9797    12/01/2016
# 9798    12/01/2016
# 9799    12/01/2016
# Name: Order Date, Length: 9800, dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True, errors='coerce')

# %%
total_revenue = df['Sales'].sum()
avg_order_value = df['Sales'].mean()

print("Total Revenue:", total_revenue)
print("Average Order Value:", avg_order_value)
# Out:
# Total Revenue: 2261536.7827
# Average Order Value: 230.76905945918367

# %%
top_regions = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
top_regions
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
df.columns = df.columns.str.strip()

df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

df = df.dropna(subset=['Order Date'])

df['Month'] = df['Order Date'].dt.month
df['Year'] = df['Order Date'].dt.year

# %%
df[['Order Date','Month','Year']].head()
# Out:
#   Order Date  Month  Year
# 0 2017-11-08     11  2017
# 1 2017-11-08     11  2017
# 2 2017-06-12      6  2017
# 3 2016-10-11     10  2016
# 4 2016-10-11     10  2016

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(5)

top_products.plot(kind='bar')
plt.title("Top 5 Products")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Project Objective
# To analyze retail sales data and extract meaningful business insights by computing key performance indicators (KPIs), identifying seasonal trends, and determining top-performing regions and products.
#
# # Key Performance Indicators (KPIs)
#
# Total Revenue: 2261536.7827
# Average Order Value: 230.76905945918367
# Top Performing Region: West : 710219.6845
#
# # Monthly Sales Trend
#
# The chart below shows monthly sales performance, helping identify seasonality and demand fluctuations.
#
# # Regional Performance
# The top-performing region contributes the highest portion of overall revenue.
# Strategic marketing and inventory optimization in this region can further increase profitability.
#
# # Seasonality Trend
# Sales demonstrate noticeable variation across months, indicating seasonal demand patterns.
# Peak months present opportunities for targeted promotional campaigns.
#
# # Revenue Concentration
# A significant share of revenue is driven by a limited number of products or regions.
# Ensuring consistent stock and supply chain efficiency for these contributors is critical.
#
# # Recommendations
#
# - Increase marketing efforts during peak months.
# - Prioritize inventory for high-performing regions.
# - Monitor underperforming months and introduce promotional discounts.
# - Implement data-driven demand forecasting for better planning.
#
# # Tools Used
#
# - Python
# - Pandas
# - Matplotlib
# - Seaborn
# - Jupyter Notebook
#
# # Conclusion
#
# The sales analysis highlights key revenue drivers, seasonal patterns, and high-performing regions.
# By leveraging these insights, the business can make data-driven decisions to optimize revenue, improve customer targeting, and enhance operational efficiency.
