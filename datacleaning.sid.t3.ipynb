# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Siddhi/Downloads/ProjectsDATA/StudentsPerformance.W1T3.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0       NaN        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       998 non-null    object
#  1   race/ethnicity               996 non-null    object
#  2   parental level of education  998 non-null    object
#  3   lunch                        987 non-null    object
#  4   test preparation course      989 non-null    object
#  5   math score                   993 non-null    float64
#  6   reading score                979 non-null    float64
#  7   writing score                988 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                          2
# race/ethnicity                  4
# parental level of education     2
# lunch                          13
# test preparation course        11
# math score                      7
# reading score                  21
# writing score                  12
# dtype: int64

# %%
df["math score"] = df["math score"].fillna(df["math score"].mean())

# %%
df["math score"]
# Out:
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# 4      76.0
#        ...
# 995    88.0
# 996    62.0
# 997    59.0
# 998    68.0
# 999    77.0
# Name: math score, Length: 1000, dtype: float64

# %%
df["math score"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
df["gender"].isnull()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df["reading score"] = df["reading score"].fillna(df["reading score"].mean())

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0       NaN        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["writing score"] = df["writing score"].fillna(df["writing score"].mean())

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0       NaN        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["math score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["reading score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["writing score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["gender"]=df["gender"].fillna("not known")

# %%
df["gender"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df["gender"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  4
# parental level of education     2
# lunch                          13
# test preparation course        11
# math score                      0
# reading score                   0
# writing score                   0
# dtype: int64

# %%
df["race/ethnicity"]=df["race/ethnicity"].fillna("not knowm")

# %%
df["race/ethnicity"]
# Out:
# 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object

# %%
df["race/ethnicity"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["lunch"] = df["lunch"].fillna("tiffin")

# %%
df["lunch"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["test preparation course"]= df["test preparation course"].fillna("incomplete")

# %%
df["test preparation course"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    2
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df = df.fillna("unknown")

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object
